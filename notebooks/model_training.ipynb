# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/customer_churn_dataset-training-master.csv")

df.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
df.shape
# Out:
# (440833, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 440833 entries, 0 to 440832
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         440832 non-null  float64
#  1   Age                440832 non-null  float64
#  2   Gender             440832 non-null  str
#  3   Tenure             440832 non-null  float64
#  4   Usage Frequency    440832 non-null  float64
#  5   Support Calls      440832 non-null  float64
#  6   Payment Delay      440832 non-null  float64
#  7   Subscription Type  440832 non-null  str
#  8   Contract Length    440832 non-null  str
#  9   Total Spend        440832 non-null  float64
#  10  Last Interaction   440832 non-null  float64
#  11  Churn              440832 non-null  float64
# dtypes: float64(9), str(3)
# memory usage: 40.4 MB

# %%
df.describe()
# Out:
#           CustomerID            Age         Tenure  Usage Frequency  \
# count  440832.000000  440832.000000  440832.000000    440832.000000
# mean   225398.667955      39.373153      31.256336        15.807494
# std    129531.918550      12.442369      17.255727         8.586242
# min         2.000000      18.000000       1.000000         1.000000
# 25%    113621.750000      29.000000      16.000000         9.000000
# 50%    226125.500000      39.000000      32.000000        16.000000
# 75%    337739.250000      48.000000      46.000000        23.000000
# max    449999.000000      65.000000      60.000000        30.000000
#
#        Support Calls  Payment Delay    Total Spend  Last Interaction  \
# count  440832.000000  440832.000000  440832.000000     440832.000000
# mean        3.604437      12.965722     631.616223         14.480868
# std         3.070218       8.258063     240.803001          8.596208
# min         0.000000       0.000000     100.000000          1.000000
# 25%         1.000000       6.000000     480.000000          7.000000
# 50%         3.000000      12.000000     661.000000         14.000000
# 75%         6.000000      19.000000     830.000000         22.000000
# max        10.000000      30.000000    1000.000000         30.000000
#
#                Churn
# count  440832.000000
# mean        0.567107
# std         0.495477
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# CustomerID           1
# Age                  1
# Gender               1
# Tenure               1
# Usage Frequency      1
# Support Calls        1
# Payment Delay        1
# Subscription Type    1
# Contract Length      1
# Total Spend          1
# Last Interaction     1
# Churn                1
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64

# %%
df = df.drop("CustomerID", axis=1)

# %%
df.head()
# Out:
#     Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0  30.0  Female    39.0             14.0            5.0           18.0
# 1  65.0  Female    49.0              1.0           10.0            8.0
# 2  55.0  Female    14.0              4.0            6.0           18.0
# 3  58.0    Male    38.0             21.0            7.0            7.0
# 4  23.0    Male    32.0             20.0            5.0            8.0
#
#   Subscription Type Contract Length  Total Spend  Last Interaction  Churn
# 0          Standard          Annual        932.0              17.0    1.0
# 1             Basic         Monthly        557.0               6.0    1.0
# 2             Basic       Quarterly        185.0               3.0    1.0
# 3          Standard         Monthly        396.0              29.0    1.0
# 4             Basic         Monthly        617.0              20.0    1.0

# %%
df = pd.get_dummies(
    df,
    columns=[
        "Gender",
        "Subscription Type",
        "Contract Length"
    ],
    drop_first = True
)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 440832 entries, 0 to 440832
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Age                         440832 non-null  float64
#  1   Tenure                      440832 non-null  float64
#  2   Usage Frequency             440832 non-null  float64
#  3   Support Calls               440832 non-null  float64
#  4   Payment Delay               440832 non-null  float64
#  5   Total Spend                 440832 non-null  float64
#  6   Last Interaction            440832 non-null  float64
#  7   Churn                       440832 non-null  float64
#  8   Gender_Male                 440832 non-null  bool
#  9   Subscription Type_Premium   440832 non-null  bool
#  10  Subscription Type_Standard  440832 non-null  bool
#  11  Contract Length_Monthly     440832 non-null  bool
#  12  Contract Length_Quarterly   440832 non-null  bool
# dtypes: bool(5), float64(8)
# memory usage: 32.4 MB

# %%
X = df.drop("Churn", axis=1)
Y = df["Churn"]

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Failed to build 'sklearn' when getting requirements to build wheel

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\kipit\appdata\local\programs\python\python314\lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\kipit\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\kipit\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\kipit\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\kipit\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\kipit\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (352665, 12)
# (88167, 12)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
# Out:
# c:\Users\kipit\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
y_pred = lr.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8965032268309004

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
dt_pred = dt.predict(X_test)
dt_accuracy = accuracy_score(y_test, dt_pred)
print("Decision Tree Accuracy:", dt_accuracy)
# Out:
# Decision Tree Accuracy: 0.9997051050846689

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_pred = rf.predict(X_test)
rf_accuracy = accuracy_score(y_test, rf_pred)
print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Random Forest Accuracy: 0.9996143681876439

# %%
results = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest"
    ],
    "Accuracy": [
        accuracy_score(y_test, y_pred),
        dt_accuracy,
        rf_accuracy
    ]
})
results
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.896503
# 1        Decision Tree  0.999705
# 2        Random Forest  0.999614

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     38063
#          1.0       1.00      1.00      1.00     50104
#
#     accuracy                           1.00     88167
#    macro avg       1.00      1.00      1.00     88167
# weighted avg       1.00      1.00      1.00     88167

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, dt_pred)
print(cm)
# Out:
# [[38051    12]
#  [   14 50090]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_predictions(
    y_test,
    dt_pred
)

plt.show()

# %%
import pandas as pd
importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': dt.feature_importances_
})
importance = importance.sort_values(
    by='Importance',
    ascending=False
)
importance.head(10)
# Out:
#                        Feature  Importance
# 3                Support Calls    0.356989
# 5                  Total Spend    0.242426
# 10     Contract Length_Monthly    0.135597
# 0                          Age    0.112876
# 4                Payment Delay    0.102466
# 6             Last Interaction    0.035016
# 1                       Tenure    0.006692
# 7                  Gender_Male    0.004583
# 9   Subscription Type_Standard    0.001717
# 8    Subscription Type_Premium    0.001041

# %%
import joblib

joblib.dump(
    dt,
    "../models/churn_model.pkl"
)
# Out:
# ['../models/churn_model.pkl']

# %%
import os

os.listdir("../models")
# Out:
# ['churn_model.pkl']

# %%
importance.head(15)
# Out:
#                        Feature  Importance
# 3                Support Calls    0.356989
# 5                  Total Spend    0.242426
# 10     Contract Length_Monthly    0.135597
# 0                          Age    0.112876
# 4                Payment Delay    0.102466
# 6             Last Interaction    0.035016
# 1                       Tenure    0.006692
# 7                  Gender_Male    0.004583
# 9   Subscription Type_Standard    0.001717
# 8    Subscription Type_Premium    0.001041
# 2              Usage Frequency    0.000587
# 11   Contract Length_Quarterly    0.000009

# %%
df["Churn"].value_counts()
# Out:
# Churn
# 1.0    249999
# 0.0    190833
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# 1.0    56.71072
# 0.0    43.28928
# Name: proportion, dtype: float64

# %%
evaluation = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest"
    ],
    "Accuracy": [
        0.896503,
        0.999705,
        0.999614
    ]
})

evaluation
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.896503
# 1        Decision Tree  0.999705
# 2        Random Forest  0.999614

# %%
df["Churn"].value_counts()
# Out:
# Churn
# 1.0    249999
# 0.0    190833
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# 1.0    56.71072
# 0.0    43.28928
# Name: proportion, dtype: float64

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     38063
#          1.0       1.00      1.00      1.00     50104
#
#     accuracy                           1.00     88167
#    macro avg       1.00      1.00      1.00     88167
# weighted avg       1.00      1.00      1.00     88167

# %%
importance.head(10).plot(
    x="Feature",
    y="Importance",
    kind="bar",
    figsize=(10,5)
)

plt.title("Feature Importance")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 440832 entries, 0 to 440832
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Age                         440832 non-null  float64
#  1   Tenure                      440832 non-null  float64
#  2   Usage Frequency             440832 non-null  float64
#  3   Support Calls               440832 non-null  float64
#  4   Payment Delay               440832 non-null  float64
#  5   Total Spend                 440832 non-null  float64
#  6   Last Interaction            440832 non-null  float64
#  7   Churn                       440832 non-null  float64
#  8   Gender_Male                 440832 non-null  bool
#  9   Subscription Type_Premium   440832 non-null  bool
#  10  Subscription Type_Standard  440832 non-null  bool
#  11  Contract Length_Monthly     440832 non-null  bool
#  12  Contract Length_Quarterly   440832 non-null  bool
# dtypes: bool(5), float64(8)
# memory usage: 32.4 MB

# %%
results
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.896503
# 1        Decision Tree  0.999705
# 2        Random Forest  0.999614

# %%
importance.head(10)
# Out:
#                        Feature  Importance
# 3                Support Calls    0.356989
# 5                  Total Spend    0.242426
# 10     Contract Length_Monthly    0.135597
# 0                          Age    0.112876
# 4                Payment Delay    0.102466
# 6             Last Interaction    0.035016
# 1                       Tenure    0.006692
# 7                  Gender_Male    0.004583
# 9   Subscription Type_Standard    0.001717
# 8    Subscription Type_Premium    0.001041

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 results
#
# NameError: name 'results' is not defined

# %%
sample = X_test.iloc[[0]]
print("Customer features:")
display(sample)
prediction = dt.predict(sample)
print("Predicted Churn:", prediction[0])
print("Actual Churn:", y_test.iloc[0])
# Out:
# Customer features:
#          Age  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 159565  23.0    10.0             16.0            8.0           16.0
#
#         Total Spend  Last Interaction  Gender_Male  Subscription Type_Premium  \
# 159565        589.0              13.0        False                       True
#
#         Subscription Type_Standard  Contract Length_Monthly  \
# 159565                       False                    False
#
#         Contract Length_Quarterly
# 159565                       True
# Predicted Churn: 1.0
# Actual Churn: 1.0

# %%
for i in range(3):
    sample = X_test.iloc[[i]]
    pred = dt.predict(sample)[0]
    actual = y_test.iloc[i]
    print(f"Customer {i+1}")
    print("Predicted", pred)
    print("Actual", actual)
    print("-"*30)
# Out:
# Customer 1
# Predicted 1.0
# Actual 1.0
# ------------------------------
# Customer 2
# Predicted 1.0
# Actual 1.0
# ------------------------------
# Customer 3
# Predicted 1.0
# Actual 1.0
# ------------------------------
